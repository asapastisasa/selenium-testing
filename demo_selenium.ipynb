# %%
# !pip install selenium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting selenium
#   Downloading selenium-4.43.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting certifi>=2026.1.4 (from selenium)
#   Downloading certifi-2026.4.22-py3-none-any.whl.metadata (2.5 kB)
# Collecting trio<1.0,>=0.31.0 (from selenium)
#   Downloading trio-0.33.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting trio-websocket<1.0,>=0.12.2 (from selenium)
#   Downloading trio_websocket-0.12.2-py3-none-any.whl.metadata (5.1 kB)
# Collecting typing_extensions<5.0,>=4.15.0 (from selenium)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting urllib3<3.0,>=2.6.3 (from urllib3[socks]<3.0,>=2.6.3->selenium)
#   Downloading urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: websocket-client<2.0,>=1.8.0 in d:\salsarahmadhiniapk\lib\site-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in d:\salsarahmadhiniapk\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (24.3.0)
# Requirement already satisfied: sortedcontainers in d:\salsarahmadhiniapk\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (2.4.0)
# Requirement already satisfied: idna in d:\salsarahmadhiniapk\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (3.7)
# Collecting outcome (from trio<1.0,>=0.31.0->selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: sniffio>=1.3.0 in d:\salsarahmadhiniapk\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in d:\salsarahmadhiniapk\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (1.17.1)
# Collecting wsproto>=0.14 (from trio-websocket<1.0,>=0.12.2->selenium)
#   Downloading wsproto-1.3.2-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in d:\salsarahmadhiniapk\lib\site-packages (from urllib3[socks]<3.0,>=2.6.3->selenium) (1.7.1)
# Requirement already satisfied: pycparser in d:\salsarahmadhiniapk\lib\site-packages (from cffi>=1.14->trio<1.0,>=0.31.0->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.16.0 in d:\salsarahmadhiniapk\lib\site-packages (from wsproto>=0.14->trio-websocket<1.0,>=0.12.2->selenium) (0.16.0)
# Downloading selenium-4.43.0-py3-none-any.whl (9.6 MB)
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.6 MB 5.2 MB/s eta 0:00:02
#    --------- ------------------------------ 2.4/9.6 MB 6.8 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.2/9.6 MB 7.5 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.5/9.6 MB 7.2 MB/s eta 0:00:01
#    -------------------------- ------------- 6.3/9.6 MB 6.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.1/9.6 MB 5.8 MB/s eta 0:00:01
#    ------------------------------------ --- 8.7/9.6 MB 6.0 MB/s eta 0:00:01
#    ---------------------------------------- 9.6/9.6 MB 5.9 MB/s eta 0:00:00
# Downloading trio-0.33.0-py3-none-any.whl (510 kB)
# Downloading trio_websocket-0.12.2-py3-none-any.whl (21 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading urllib3-2.6.3-py3-none-any.whl (131 kB)
# Downloading certifi-2026.4.22-py3-none-any.whl (135 kB)
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Downloading wsproto-1.3.2-py3-none-any.whl (24 kB)
# Installing collected packages: wsproto, urllib3, typing_extensions, outcome, certifi, trio, trio-websocket, selenium
#
#    ---------------------------------------- 0/8 [wsproto]
#    ----- ---------------------------------- 1/8 [urllib3]
#    ----- ---------------------------------- 1/8 [urllib3]
#    ----- ---------------------------------- 1/8 [urllib3]
#    ----- ---------------------------------- 1/8 [urllib3]
#    ----- ---------------------------------- 1/8 [urllib3]
#    ----- ---------------------------------- 1/8 [urllib3]
#    ----- ---------------------------------- 1/8 [urllib3]
#    ----- ---------------------------------- 1/8 [urllib3]
#    ----- ---------------------------------- 1/8 [urllib3]
#    ---------- ----------------------------- 2/8 [typing_extensions]
#    --------------- ------------------------ 3/8 [outcome]
#    -------------------- ------------------- 4/8 [certifi]
#    ------------------------- -------------- 5/8 [trio]
#    ------------------------- -------------- 5/8 [trio]
#    ------------------------- -------------- 5/8 [trio]
#    ------------------------- -------------- 5/8 [trio]
#    ------------------------- -------------- 5/8 [trio]
#    ------------------------- -------------- 5/8 [trio]
#    ------------------------- -------------- 5/8 [trio]
#    ------------------------- -------------- 5/8 [trio]
#    ------------------------- -------------- 5/8 [trio]
#    ------------------------- -------------- 5/8 [trio]
#    ------------------------- -------------- 5/8 [trio]
#    ------------------------- -------------- 5/8 [trio]
#    ------------------------- -------------- 5/8 [trio]
#    ------------------------- -------------- 5/8 [trio]
#    ------------------------- -------------- 5/8 [trio]
#    ------------------------- -------------- 5/8 [trio]
#    ------------------------- -------------- 5/8 [trio]
#    ------------------------- -------------- 5/8 [trio]
#    ------------------------- -------------- 5/8 [trio]
#    ------------------------- -------------- 5/8 [trio]
#    ------------------------- -------------- 5/8 [trio]
#    ------------------------- -------------- 5/8 [trio]
#    ------------------------- -------------- 5/8 [trio]
#    ------------------------- -------------- 5/8 [trio]
#    ------------------------- -------------- 5/8 [trio]
#    ------------------------- -------------- 5/8 [trio]
#    ------------------------- -------------- 5/8 [trio]
#    ------------------------- -------------- 5/8 [trio]
#    ------------------------- -------------- 5/8 [trio]
#    ------------------------- -------------- 5/8 [trio]
#    ------------------------- -------------- 5/8 [trio]
#    ------------------------- -------------- 5/8 [trio]
#    ------------------------- -------------- 5/8 [trio]
#    ------------------------- -------------- 5/8 [trio]
#    ------------------------------ --------- 6/8 [trio-websocket]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ----------------------------------- ---- 7/8 [selenium]
#    ---------------------------------------- 8/8 [selenium]
#
# Successfully installed certifi-2026.4.22 outcome-1.3.0.post0 selenium-4.43.0 trio-0.33.0 trio-websocket-0.12.2 typing_extensions-4.15.0 urllib3-2.6.3 wsproto-1.3.2

# %%
from selenium import webdriver

driver = webdriver.Chrome()
driver.get("https://www.saucedemo.com")

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time

driver = webdriver.Chrome()
driver.get("https://www.saucedemo.com")

time.sleep(2)

driver.find_element(By.ID, "user-name").send_keys("standard_user")
driver.find_element(By.ID, "password").send_keys("secret_sauce")
driver.find_element(By.ID, "login-button").click()
